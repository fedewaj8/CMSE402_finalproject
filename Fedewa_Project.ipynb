# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
alldt = pd.read_csv('Environment_Temperature_change_E_All_Data_NOFLAG.csv', encoding='latin-1')

# %%
alldt
# Out:
#       Area Code         Area  Months Code               Months  Element Code  \
# 0             2  Afghanistan         7001              January          7271
# 1             2  Afghanistan         7001              January          6078
# 2             2  Afghanistan         7002             February          7271
# 3             2  Afghanistan         7002             February          6078
# 4             2  Afghanistan         7003                March          7271
# ...         ...          ...          ...                  ...           ...
# 9651       5873         OECD         7018          JunJulAug          6078
# 9652       5873         OECD         7019          SepOctNov          7271
# 9653       5873         OECD         7019          SepOctNov          6078
# 9654       5873         OECD         7020  Meteorological year          7271
# 9655       5873         OECD         7020  Meteorological year          6078
#
# ...

# %%
alldt.keys()
# Out:
# Index(['Area Code', 'Area', 'Months Code', 'Months', 'Element Code', 'Element',
#        'Unit', 'Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967',
#        'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975',
#        'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983',
#        'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991',
#        'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999',
#        'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015',
#        'Y2016', 'Y2017', 'Y2018', 'Y2019'],
#       dtype='object')

# %%
alldt.Area.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belgium-Luxembourg', 'Belize', 'Benin',
#        'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, mainland', 'China, Taiwan Province of',
#        'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire",
# ...

# %%
regions = 'World', 'Africa',\
       'Eastern Africa', 'Middle Africa', 'Northern Africa',\
       'Southern Africa', 'Western Africa', 'Americas',\
       'Northern America', 'Central America', 'Caribbean',\
       'South America', 'Asia', 'Central Asia', 'Eastern Asia',\
       'Southern Asia', 'South-Eastern Asia', 'Western Asia', 'Europe',\
       'Eastern Europe', 'Northern Europe', 'Southern Europe',\
       'Western Europe', 'Oceania', 'Australia and New Zealand',\
       'Melanesia', 'Micronesia', 'Polynesia', 'European Union'

# %%
regions
# Out:
# ('World',
#  'Africa',
#  'Eastern Africa',
#  'Middle Africa',
#  'Northern Africa',
#  'Southern Africa',
#  'Western Africa',
#  'Americas',
#  'Northern America',
#  'Central America',
#  'Caribbean',
#  'South America',
#  'Asia',
#  'Central Asia',
#  'Eastern Asia',
#  'Southern Asia',
#  'South-Eastern Asia',
#  'Western Asia',
#  'Europe',
#  'Eastern Europe',
#  'Northern Europe',
#  'Southern Europe',
#  'Western Europe',
#  'Oceania',
#  'Australia and New Zealand',
#  'Melanesia',
#  'Micronesia',
#  'Polynesia',
#  'European Union')

# %%
alldt[alldt['Months Code'] == 7020][alldt[alldt['Months Code'] == 7020]['Area'] == 'United States of America'].loc[7920]
# Out:
# Area Code                            231
# Area            United States of America
# Months Code                         7020
# Months               Meteorological year
# Element Code                        7271
#                           ...
# Y2015                              1.508
# Y2016                              2.197
# Y2017                              1.408
# Y2018                              1.244
# Y2019                              1.011
# Name: 7920, Length: 66, dtype: object

# %%
plt.plot(list(alldt.loc[7920])[7:])

# %%
oneten = pd.read_csv('FAOSTAT_data_1-10-2022.csv')

# %%
MetYear = oneten[oneten['Months'] == 'Meteorological year']

# %%
Areas = MetYear['Area'].unique()

# %%
len(Areas)
# Out:
# 247

# %%
US = oneten[oneten['Area'] == 'United States of America'][oneten[oneten['Area'] == 'United States of America']['Months'] == 'Meteorological year']

# %%
yearssince = US['Year']-min(US['Year'])

# %%
angyearssince = 2*np.pi*yearssince/max(yearssince)

# %%
US
# Out:
#        Domain Code              Domain  Area Code (FAO)  \
# 217098          ET  Temperature change              231
# 217099          ET  Temperature change              231
# 217100          ET  Temperature change              231
# 217101          ET  Temperature change              231
# 217102          ET  Temperature change              231
# 217103          ET  Temperature change              231
# 217104          ET  Temperature change              231
# 217105          ET  Temperature change              231
# 217106          ET  Temperature change              231
# 217107          ET  Temperature change              231
# 217108          ET  Temperature change              231
# 217109          ET  Temperature change              231
# 217110          ET  Temperature change              231
# 217111          ET  Temperature change              231
# 217112          ET  Temperature change              231
# 217113          ET  Temperature change              231
# ...

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,10))
ax.plot(angyearssince, US['Value'])

# %%
plt.plot(US['Year'], US['Value'])

# %%
len(Areas)
# Out:
# 247

# %%
Areas[211]
# Out:
# 'Svalbard and Jan Mayen Islands'

# %%
fig = plt.figure(figsize=(20,10))
for area in Areas:
    if area != Areas[211] or area == Areas[211]:
        current = MetYear[MetYear['Area'] == area]
        plt.plot(current['Year'],current['Value'],label=area)
#plt.legend()
plt.axhline(y=0,c='k')
plt.ylabel('Temperature Change',fontsize=15)
plt.xlabel('Year',fontsize=15)
# Out:
# Text(0.5, 0, 'Year')

# %%
labels = list(np.floor(np.arange(1961,2019,(2019-1961)/9)))
s_lab = []
for year in labels:
    s_lab.append(str(year))
s_lab
# Out:
# ['1961.0',
#  '1967.0',
#  '1973.0',
#  '1980.0',
#  '1986.0',
#  '1993.0',
#  '1999.0',
#  '2006.0',
#  '2012.0']

# %%
Areas
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belgium-Luxembourg', 'Belize', 'Benin',
#        'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, mainland', 'China, Taiwan Province of',
#        'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "C?te d'Ivoire",
# ...

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,10))
for reg in regions:

    current = MetYear[MetYear['Area'] == reg]
    yrs = current['Year']
    yrssince = yrs-min(yrs)
    angyrssince = 2*np.pi*yrssince/max(yrssince)
#         ax.set_xticklabels(s_lab)
    ax.plot(angyrssince,current['Value'],label=reg)

#plt.legend()
#plt.axhline(y=0,c='r')
#plt.ylabel('Temperature Anomaly')
#plt.xlabel('Year')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-90bc69005160> in <module>
#       4     current = MetYear[MetYear['Area'] == reg]
#       5     yrs = current['Year']
# ----> 6     yrssince = yrs-min(yrs)
#       7     angyrssince = 2*np.pi*yrssince/max(yrssince)
#       8 #         ax.set_xticklabels(s_lab)
#
# ValueError: min() arg is an empty sequence

# %%
MetYear
# Out:
#        Domain Code              Domain  Area Code (FAO)         Area  \
# 960             ET  Temperature change                2  Afghanistan
# 961             ET  Temperature change                2  Afghanistan
# 962             ET  Temperature change                2  Afghanistan
# 963             ET  Temperature change                2  Afghanistan
# 964             ET  Temperature change                2  Afghanistan
# ...            ...                 ...              ...          ...
# 229920          ET  Temperature change              181     Zimbabwe
# 229921          ET  Temperature change              181     Zimbabwe
# 229922          ET  Temperature change              181     Zimbabwe
# 229923          ET  Temperature change              181     Zimbabwe
# 229924          ET  Temperature change              181     Zimbabwe
#
#         Element Code             Element  Months Code               Months  \
# ...

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,10))
for area in Areas:
    if area != Areas[211]: #excluding Svalbard
        current = MetYear[MetYear['Area'] == area]
        yrs = current['Year']
        yrssince = yrs-min(yrs)
        angyrssince = 2*np.pi*yrssince/max(yrssince)
        ax.set_xticklabels(s_lab)
        ax.plot(angyrssince,current['Value'],label=area)
    
#plt.legend()
#plt.axhline(y=0,c='r')
#plt.ylabel('Temperature Anomaly')
#plt.xlabel('Year')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d436d8550136> in <module>
# ----> 1 fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,10))
#       2 for area in Areas:
#       3     if area != Areas[211]: #excluding Svalbard
#       4         current = MetYear[MetYear['Area'] == area]
#       5         yrs = current['Year']
#
# NameError: name 'plt' is not defined

# %%
alldt.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   °C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   °C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   °C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   °C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   °C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# ...

# %%
alldt_evoth = alldt.iloc[0::2]

# %%
alldt_evoth.dropna()['Area'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antarctica', 'Argentina', 'Australia', 'Austria',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Cambodia', 'Cameroon', 'Canada',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'China, Hong Kong SAR', 'China, Macao SAR',
#        'China, mainland', 'China, Taiwan Province of',
#        'Cocos (Keeling) Islands', 'Colombia', 'Congo', "Côte d'Ivoire",
#        'Cuba', 'Cyprus', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eswatini', 'Faroe Islands', 'Fiji',
# ...

# %%
alldt.iloc[0:,1::]
# Out:
#              Area  Months Code               Months  Element Code  \
# 0     Afghanistan         7001              January          7271
# 1     Afghanistan         7001              January          6078
# 2     Afghanistan         7002             February          7271
# 3     Afghanistan         7002             February          6078
# 4     Afghanistan         7003                March          7271
# ...           ...          ...                  ...           ...
# 9651         OECD         7018          JunJulAug          6078
# 9652         OECD         7019          SepOctNov          7271
# 9653         OECD         7019          SepOctNov          6078
# 9654         OECD         7020  Meteorological year          7271
# 9655         OECD         7020  Meteorological year          6078
#
#                  Element Unit  Y1961  Y1962  Y1963  Y1964  ...  Y2010  Y2011  \
# 0     Temperature change   °C  0.777  0.062  2.744 -5.232  ...  3.601  1.179
# ...

# %%
countries = ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
       'Anguilla', 'Antarctica', 'Argentina', 'Australia', 'Austria',
       'Bahamas', 'Bahrain', 'Bangladesh', 'Belize', 'Benin', 'Bhutan',
       'Bolivia (Plurinational State of)', 'Botswana', 'Brazil',
       'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
       'Burkina Faso', 'Cambodia', 'Cameroon', 'Canada',
       'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
       'China', 'China, Hong Kong SAR', 'China, Macao SAR',
       'China, mainland', 'China, Taiwan Province of',
       'Cocos (Keeling) Islands', 'Colombia', 'Congo', "Côte d'Ivoire",
       'Cuba', 'Cyprus', "Democratic People's Republic of Korea",
       'Democratic Republic of the Congo', 'Denmark', 'Dominica',
       'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
       'Equatorial Guinea', 'Eswatini', 'Faroe Islands', 'Fiji',
       'Finland', 'France', 'French Guiana', 'French Polynesia',
       'French Southern and Antarctic Territories', 'Gabon', 'Gambia',
       'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
       'Guadeloupe', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana',
       'Haiti', 'Holy See', 'Honduras', 'Hungary', 'Iceland', 'India',
       'Indonesia', 'Iran (Islamic Republic of)', 'Iraq', 'Ireland',
       'Isle of Man', 'Israel', 'Italy', 'Japan', 'Jordan', 'Kenya',
       'Kuwait', "Lao People's Democratic Republic", 'Lebanon', 'Lesotho',
       'Liberia', 'Libya', 'Liechtenstein', 'Madagascar', 'Malawi',
       'Malaysia', 'Mali', 'Malta', 'Martinique', 'Mauritania',
       'Mauritius', 'Mexico', 'Monaco', 'Mongolia', 'Morocco',
       'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Netherlands',
       'Netherlands Antilles (former)', 'New Caledonia', 'New Zealand',
       'Nicaragua', 'Niger', 'Nigeria', 'Norway', 'Oman', 'Pakistan',
       'Palestine', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
       'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Republic of Korea',
       'Réunion', 'Romania',
       'Saint Helena, Ascension and Tristan da Cunha', 'Saint Lucia',
       'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
       'San Marino', 'Saudi Arabia', 'Senegal', 'Seychelles',
       'Sierra Leone', 'Somalia', 'South Africa', 'Spain', 'Sri Lanka',
       'Suriname', 'Svalbard and Jan Mayen Islands', 'Sweden',
       'Switzerland', 'Syrian Arab Republic', 'Thailand', 'Togo', 'Tonga',
       'Tunisia', 'Turkey', 'Tuvalu', 'Uganda', 'United Arab Emirates',
       'United Kingdom', 'United Republic of Tanzania',
       'United States of America', 'United States Virgin Islands',
       'Uruguay', 'Vanuatu', 'Venezuela (Bolivarian Republic of)',
       'Viet Nam', 'Wallis and Futuna Islands', 'Western Sahara',
       'Zambia', 'Zimbabwe']

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,10))
for area in countries:
#     if area != Areas[211]: #excluding Svalbard
    current = MetYear[MetYear['Area'] == area]
    yrs = current['Year']
    yrssince = yrs-min(yrs)
    angyrssince = 2*np.pi*yrssince/max(yrssince)
#         ax.set_xticklabels(s_lab)
    ax.plot(angyrssince,current['Value'],label=area)
    
#plt.legend()
#plt.axhline(y=0,c='r')
#plt.ylabel('Temperature Anomaly')
#plt.xlabel('Year')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-0871f10246b6> in <module>
#       4     current = MetYear[MetYear['Area'] == area]
#       5     yrs = current['Year']
# ----> 6     yrssince = yrs-min(yrs)
#       7     angyrssince = 2*np.pi*yrssince/max(yrssince)
#       8 #         ax.set_xticklabels(s_lab)
#
# ValueError: min() arg is an empty sequence

# %%
for i in range(1,len(angyearssince)):
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,10))
    ############# Plot #############

#     ax.plot(angyearssince[:i], US['Value'][:i])
    for area in countries:
#     if area != Areas[211]: #excluding Svalbard
        current = MetYear[MetYear['Area'] == area]
        yrs = current['Year']
        yrssince = yrs-min(yrs)
        angyrssince = 2*np.pi*yrssince/max(yrssince)
#         ax.set_xticklabels(s_lab)
        ax.plot(angyrssince[:i],current['Value'][:i],label=area)
    
    ############# Save to file #############
    
    fig.savefig('Countrytemp_{:0>3}'.format(i))   # save the figure to file
    plt.close(fig)    # close the figure window
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-163a99b1ac77> in <module>
#       8         current = MetYear[MetYear['Area'] == area]
#       9         yrs = current['Year']
# ---> 10         yrssince = yrs-min(yrs)
#      11         angyrssince = 2*np.pi*yrssince/max(yrssince)
#      12 #         ax.set_xticklabels(s_lab)
#
# ValueError: min() arg is an empty sequence
